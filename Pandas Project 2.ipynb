# %%
import pandas as pd

# %%
data = pd.read_csv('Fast_Food_Restaurants_US.csv')
data
# Out:
#       Unnamed: 0                      address  \
# 0              0             800 N Canal Blvd
# 1              1             800 N Canal Blvd
# 2              2          206 Wears Valley Rd
# 3              3                 3652 Parkway
# 4              4         2118 Mt Zion Parkway
# 5              5         9768 Grand River Ave
# 6              6         13600 W McNichols Rd
# 7              7          4111 Oceanside Blvd
# 8              8           162 Old Country Rd
# 9              9          1407 S Stockton Ave
# 10            10               208 W Mason St
# 11            11               5801 Highway 6
# 12            12           3454 Manchester Rd
# 13            13               1500 E Main St
# 14            14         1190 W Foothill Blvd
# 15            15                601 N Main St
# 16            16          1927 Woodville Road
# 17            17               6316 W 89th St
# 18            18            3105 Highway 80 E
# ...

# %% [markdown]
# ##### Q1. Find out the FIrst 10 elements from the dataset

# %%
data.head(10)
# Out:
#    Unnamed: 0               address  \
# 0           0      800 N Canal Blvd
# 1           1      800 N Canal Blvd
# 2           2   206 Wears Valley Rd
# 3           3          3652 Parkway
# 4           4  2118 Mt Zion Parkway
# 5           5  9768 Grand River Ave
# 6           6  13600 W McNichols Rd
# 7           7   4111 Oceanside Blvd
# 8           8    162 Old Country Rd
# 9           9   1407 S Stockton Ave
#
#                                      categories          city country  \
# 0  American Restaurant and Fast Food Restaurant     Thibodaux      US
# 1                         Fast Food Restaurants     Thibodaux      US
# 2                          Fast Food Restaurant  Pigeon Forge      US
# 3                                     Fast Food  Pigeon Forge      US
# 4                          Fast Food Restaurant        Morrow      US
# 5                          Fast Food Restaurant       Detroit      US
# ...

# %% [markdown]
# ##### Q2. Find out the last 10 values from the given dataset

# %%
data.tail(10)
# Out:
#       Unnamed: 0                     address             categories  \
# 9990        9990            814 N Ventura Rd   Fast Food Restaurant
# 9991        9991  401 W Channel Islands Blvd   Fast Food Restaurant
# 9992        9992  351 E Channel Islands Blvd   Fast Food Restaurant
# 9993        9993            1741 Pacific Ave  Fast Food Restaurants
# 9994        9994        5062 Styers Ferry Rd  Fast Food Restaurants
# 9995        9995           3460 Robinhood Rd  Fast Food Restaurants
# 9996        9996        3069 Kernersville Rd  Fast Food Restaurants
# 9997        9997               838 S Main St  Fast Food Restaurants
# 9998        9998         1702 Glendale Dr SW  Fast Food Restaurants
# 9999        9999             1405 W Broad St  Fast Food Restaurants
#
#                city country   latitude   longitude             name  \
# 9990   Port Hueneme      US  34.155100 -119.195200  Jack in the Box
# 9991   Port Hueneme      US  34.176370 -119.208850       McDonald's
# ...

# %% [markdown]
# ##### Q3. Find out the data types of each columns

# %%
data.dtypes
# Out:
# Unnamed: 0      int64
# address        object
# categories     object
# city           object
# country        object
# latitude      float64
# longitude     float64
# name           object
# postalCode     object
# province       object
# websites       object
# dtype: object

# %% [markdown]
# ##### Q4. Drop the unwanted columns from the datasets

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'address', 'categories', 'city', 'country', 'latitude',
#        'longitude', 'name', 'postalCode', 'province', 'websites'],
#       dtype='object')

# %%
for i in data.columns:
    if i == 'Unnamed: 0' or i == 'latitude' or i == 'longitude':
        data.drop(i,axis=1,inplace=True)

# %%
data
# Out:
#                           address  \
# 0                800 N Canal Blvd
# 1                800 N Canal Blvd
# 2             206 Wears Valley Rd
# 3                    3652 Parkway
# 4            2118 Mt Zion Parkway
# 5            9768 Grand River Ave
# 6            13600 W McNichols Rd
# 7             4111 Oceanside Blvd
# 8              162 Old Country Rd
# 9             1407 S Stockton Ave
# 10                 208 W Mason St
# 11                 5801 Highway 6
# 12             3454 Manchester Rd
# 13                 1500 E Main St
# 14           1190 W Foothill Blvd
# 15                  601 N Main St
# 16            1927 Woodville Road
# 17                 6316 W 89th St
# 18              3105 Highway 80 E
# 19            2860 E Paris Ave SE
# 20           2424 E State Road 44
# 21                  1611 Broadway
# 22                1720 Walton Way
# 23          17620 Grand River Ave
# 24          196 Massachusetts Ave
# 25                  1224 State St
# ...

# %% [markdown]
# ##### Q5. Find out the total columns, rows, & the memory of the dataframe

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
# address       10000 non-null object
# categories    10000 non-null object
# city          10000 non-null object
# country       10000 non-null object
# name          10000 non-null object
# postalCode    10000 non-null object
# province      10000 non-null object
# websites      10000 non-null object
# dtypes: object(8)
# memory usage: 312.5+ KB

# %% [markdown]
# ##### Q6. Find out the restaurant names under the 'American Restaurants' category in all over US?

# %%
data.columns
# Out:
# Index(['address', 'categories', 'city', 'country', 'name', 'postalCode',
#        'province', 'websites'],
#       dtype='object')

# %%
data[data['categories'].str.contains('American Restaurant')]['name']
# Out:
# 0             SONIC Drive In
# 107            Boston Market
# 114                   Arby's
# 125                   Arby's
# 137              Chick-Fil-A
# 165                   Arby's
# 218             Golden Chick
# 230                   Arby's
# 240                   Arby's
# 251                   Arby's
# 460                   Arby's
# 566                   Arby's
# 597              Chick-fil-A
# 603              Chick-fil-A
# 609          In-N-Out Burger
# 612              Chick-fil-A
# 616              Chick-fil-A
# 619              Chick-fil-A
# 646                   Arby's
# 649                   Arby's
# 652                   Arby's
# 653                   Arby's
# 659                   Arby's
# 660                   Arby's
# 672                 Spangles
# 688                   Arby's
# 754                   Arby's
# 756              Chick-Fil-A
# 957                   Arby's
# 959                   Arby's
#                 ...
# 9254             Chick-fil-A
# ...

# %% [markdown]
# ##### Q7. How many Fast Food Restaurants in US? *********************************************

# %%
len(data[data['categories'].str.contains('fAst food restaurant',case=False)])
# Out:
# 8199

# %% [markdown]
# ##### Q8. Find out the addresses of the icecream shop in 'Missouri CIty'

# %%
d = data[data['city'] == 'Missouri City']
d[d['categories'].str.contains('ice cream shop',case=False)]['address']
# Out:
# 11    5801 Highway 6
# Name: address, dtype: object

# %% [markdown]
# ##### Q9. Find out the fats food restaurants in Los Angeles

# %%
data.columns
# Out:
# Index(['address', 'categories', 'city', 'country', 'name', 'postalCode',
#        'province', 'websites'],
#       dtype='object')

# %%
d = data[data['city'] == 'Los Angeles']
print(d[d['categories'].str.contains('Fast Food Restaurant')]['name'])
len(d[d['categories'].str.contains('Fast Food Restaurant')]['name'])
# Out:
# 324          Foster's Freeze
# 572               McDonald's
# 579               McDonald's
# 1685             Burger King
# 1818    Einstein Bros Bagels
# 3581         Jack in the Box
# 3658         Jack in the Box
# 3662         Jack in the Box
# 3859              McDonald's
# 3868              McDonald's
# 4003             Burger King
# 4004             Burger King
# 4005             Burger King
# 4006             Burger King
# 4007             Burger King
# 4009             Burger King
# 4011             Burger King
# 4012             Burger King
# 4189             Chick-Fil-A
# 4256               Taco Bell
# 5043              McDonald's
# 5138                  Subway
# 5302              McDonald's
# 5310              McDonald's
# 5311              McDonald's
# 5811     Rick's Drive In Out
# 7094         Jack in the Box
# 7456                Del Taco
# 7762             Chick-Fil-A
# 8195                     KFC
# 9549              McDonald's
# Name: name, dtype: object
# 31

# %% [markdown]
# ##### Q10 Findout the restaurants where postal code is '11901'

# %%
data.columns
# Out:
# Index(['address', 'categories', 'city', 'country', 'name', 'postalCode',
#        'province', 'websites'],
#       dtype='object')

# %%
data[data['postalCode']=='11901']
# Out:
#                  address             categories       city country  \
# 8     162 Old Country Rd  Fast Food Restaurants  Riverhead      US
# 9173      1770 W Main St   Fast Food Restaurant  Riverhead      US
#
#             name postalCode province  \
# 8       7-Eleven      11901       NY
# 9173  McDonald's      11901       NY
#
#                                                websites
# 8     http://www.7-eleven.com/?yext=39326,http://www...
# 9173      http://mcdonalds.com,http://www.mcdonalds.com

# %% [markdown]
# ##### Q11. How many Mcdonald's are in all over US?

# %%
len(data[data['name'] == "McDonald's"])
# Out:
# 1898

# %% [markdown]
# ##### Q12.How Many CItys Of US We Have In Our DataFrame?

# %%
data['city'].nunique()
# Out:
# 2764

# %% [markdown]
# ##### Q13. List the names of citys where 'SubWay' is present

# %%
data[data['name'] == 'Subway']['city']
# Out:
# 332         Cartersville
# 333               Bowdon
# 337               Albany
# 338               Albany
# 437         Belle Vernon
# 438            Aliquippa
# 533             Chalfont
# 548          Saint Clair
# 549     Schuylkill Haven
# 550           Bloomsburg
# 551             Columbia
# 552               Denver
# 568            Hyde Park
# 569            Cambridge
# 570              Maynard
# 574            Woodstock
# 575               Layton
# 624            Tallmadge
# 625           Grove City
# 626           Youngstown
# 629       Cuyahoga Falls
# 630               Canton
# 639            La Grange
# 642            San Diego
# 739         Spring Grove
# 740           Waynesboro
# 741            Snow Shoe
# 742            Mansfield
# 743            Camp Hill
# 744       Roaring Spring
#               ...
# 9606                 Ada
# 9612        Mifflinville
# 9613        Central City
# 9620         Rock Spring
# 9629          Pocahontas
# 9646       Bowling Green
# ...

# %% [markdown]
# ##### Q14. What is the website of Dairy Queen,Monahans City?

# %%
d = data[data['name']=='Dairy Queen'] 
d[d['city']=='Monahans']['websites']
# Out:
# 9    http://www.dairyqueen.com,http://api.citygridm...
# Name: websites, dtype: object

# %% [markdown]
# ##### Q15. List the restaurants name, address, and postal code of the restaurants of the new York City

# %%
data[data['city']=='New York'][['address','name','postalCode']]
# Out:
#                           address                  name postalCode
# 27    1188 Avenue of The Americas            McDonald's      10036
# 28                114 Delancey St            McDonald's      10002
# 1868                3633 Broadway   Crown Fried Chicken      10031
# 2000                 317 Broadway            McDonald's      10007
# 2007                 262 Canal St            McDonald's      10013
# 2098                 1997 3rd Ave            McDonald's      10029
# 2100                 18 E 42nd St            McDonald's      10017
# 2106                 136 W 3rd St            McDonald's      10012
# 2107                1651 Broadway            McDonald's      10019
# 2890                  302 5th Ave        Dunkin' Donuts      10001
# 2891                  269 8th Ave        Dunkin' Donuts      10011
# 3114                  225 1st Ave              Checkers      10003
# 3115                  225 1st Ave              Checkers      10003
# ...

# %% [markdown]
# ##### Q16. Check the null values from the dataframe

# %%
data.isnull().sum()
# Out:
# address       2
# categories    2
# city          2
# country       2
# name          2
# postalCode    2
# province      2
# websites      2
# dtype: int64

# %%
import numpy as np
data.loc[1021]=np.nan
data.loc[5771]=np.nan

# %% [markdown]
# ##### Q17. Delete All The Null Values From The DataFrame

# %%
data.dropna(axis=0,inplace=True)

# %%
data.isnull().sum()
# Out:
# address       0
# categories    0
# city          0
# country       0
# name          0
# postalCode    0
# province      0
# websites      0
# dtype: int64

# %% [markdown]
# ##### Q18.Which Restaurants have more branches in US?

# %%
data['name'].value_counts()
# Out:
# McDonald's                                         1898
# Taco Bell                                          1031
# Burger King                                         833
# Subway                                              776
# Arby's                                              663
# Wendy's                                             628
# Jack in the Box                                     330
# Pizza Hut                                           230
# Dairy Queen                                         218
# Domino's Pizza                                      215
# Chick-fil-A                                         206
# KFC                                                 162
# SONIC Drive In                                      125
# Jimmy John's                                        119
# Carl's Jr.                                          112
# Hardee's                                             99
# Krystal                                              82
# ...
